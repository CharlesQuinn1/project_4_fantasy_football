# %%
# Import our dependencies
import hvplot.pandas
import numpy as np
import pandas as pd
import requests
import scipy.stats as st
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler,OneHotEncoder
#  Import and read the charity_data.csv.
import pandas as pd 
df = pd.read_csv("clean_df_final.csv")
df.head()
# Out:
#              Player  Pos          School  AP Ranking      Ht   Wt  40yd  \
# 0      John Abraham  OLB  South Carolina         NaN   4-Jun  252  4.55
# 1   Shaun Alexander   RB         Alabama         NaN  Jun-00  218  4.58
# 2    Darnell Alford   OT     Boston Col.         NaN   4-Jun  334  5.56
# 3  Rashard Anderson   CB   Jackson State         NaN   2-Jun  206  4.55
# 4   LaVar Arrington  OLB      Penn State         NaN   3-Jun  250  4.53
#
#    Vertical  Bench  Broad Jump  ...  rush_att  rush_yds  rush_tds    rec  \
# 0       NaN    NaN         NaN  ...       NaN       NaN       NaN    NaN
# 1       NaN    NaN         NaN  ...    2187.0    9453.0     100.0  215.0
# 2      25.0   23.0        94.0  ...       NaN       NaN       NaN    NaN
# 3      34.0    NaN       123.0  ...       NaN       NaN       NaN    NaN
# 4       NaN    NaN         NaN  ...       NaN       NaN       NaN    NaN
#
#    rec_yds  rec_tds    tkl def_int     sk    college_univ
# ...

# %%
df1 = df.drop(['School','Ht','player_id','tm','hof','pos','position_standard','college_univ','AP Ranking'],axis=1)

df1.head()
# Out:
#              Player  Pos   Wt  40yd  Vertical  Bench  Broad Jump  3Cone  \
# 0      John Abraham  OLB  252  4.55       NaN    NaN         NaN    NaN
# 1   Shaun Alexander   RB  218  4.58       NaN    NaN         NaN    NaN
# 2    Darnell Alford   OT  334  5.56      25.0   23.0        94.0   8.48
# 3  Rashard Anderson   CB  206  4.55      34.0    NaN       123.0   7.18
# 4   LaVar Arrington  OLB  250  4.53       NaN    NaN         NaN    NaN
#
#    Shuttle  Year  ...  pass_int  rush_att  rush_yds  rush_tds    rec  rec_yds  \
# 0      NaN  2000  ...       NaN       NaN       NaN       NaN    NaN      NaN
# 1      NaN  2000  ...       NaN    2187.0    9453.0     100.0  215.0   1520.0
# 2     4.98  2000  ...       NaN       NaN       NaN       NaN    NaN      NaN
# 3     4.15  2000  ...       NaN       NaN       NaN       NaN    NaN      NaN
# 4      NaN  2000  ...       NaN       NaN       NaN       NaN    NaN      NaN
#
#    rec_tds    tkl  def_int     sk
# ...

# %%
Object = df1.dtypes[df.dtypes == "object"].index.tolist()
print(Object)
# Out:
# ['Player', 'Pos']

# %%
del_item = Object.pop(0)

# %%
Object
# Out:
# ['Pos']

# %%
df[Object].nunique()
# Out:
# Pos    17
# dtype: int64

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(df1[Object]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(Object)
encode_df.head()
# Out:
# c:\Users\Bryan\anaconda3\envs\dev\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Bryan\deep-learning-challenge-module-21\Starter_Code\ALL Pos model.ipynb Cell 7 line 8
#       <a href='vscode-notebook-cell:/c%3A/Users/Bryan/deep-learning-challenge-module-21/Starter_Code/ALL%20Pos%20model.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> encode_df = pd.DataFrame(enc.fit_transform(df1[Object]))
#       <a href='vscode-notebook-cell:/c%3A/Users/Bryan/deep-learning-challenge-module-21/Starter_Code/ALL%20Pos%20model.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> # Add the encoded variable names to the dataframe
# ...
